# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib
x = np.linspace(1, 5 , 11)
y = x ** 2
fig, axes = plt.subplots(1, 2, figsize=(10,4))
      
axes[0].plot(x, x**2, x, np.exp(x))
axes[0].set_title("Normal scale")

axes[1].plot(x, x**2, x, np.exp(x))
axes[1].set_yscale("log")
axes[1].set_title("Logarithmic scale (y)");

# %%
x
# Out:
# array([1. , 1.4, 1.8, 2.2, 2.6, 3. , 3.4, 3.8, 4.2, 4.6, 5. ])

# %%
y
# Out:
# array([ 1.  ,  1.96,  3.24,  4.84,  6.76,  9.  , 11.56, 14.44, 17.64,
#        21.16, 25.  ])

# %%
fig, ax = plt.subplots(figsize=(10, 4))

ax.plot(x, x**2, x, x**3, lw=2)

ax.set_xticks([1, 2, 3, 4, 5])
ax.set_xticklabels([r'$\alpha$', r'$\beta$', r'$\gamma$', r'$\delta$', r'$\epsilon$'], fontsize=18,color="blue")

yticks = [0, 50, 100, 150]
ax.set_yticks(yticks)
ax.set_yticklabels(["$%.1f$" % y for y in yticks], fontsize=18);

# %%
fig, ax = plt.subplots(1, 1)

ax.plot(x, x**2, x, np.exp(x))
ax.set_title("scientific notation")

ax.set_yticks([0, 50, 100, 150])

from matplotlib import ticker
formatter = ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True) 
formatter.set_powerlimits((-1,1)) 
ax.yaxis.set_major_formatter(formatter)

# %%
matplotlib.rcParams['xtick.major.pad'] = 5
matplotlib.rcParams['ytick.major.pad'] = 5

fig, ax = plt.subplots(1, 1)

ax.plot(x, x**2, x, np.exp(x))
ax.set_yticks([0, 50, 100, 150])

ax.set_title("label and axis spacing")

ax.xaxis.labelpad = 5
ax.yaxis.labelpad = 5

ax.set_xlabel("x")
ax.set_ylabel("y");

# %%
matplotlib.rcParams['xtick.major.pad'] = 10
matplotlib.rcParams['ytick.major.pad'] = 10

# %%
fig, ax = plt.subplots(1, 1)
ax.plot(x, x**2, x, np.exp(x));

# %%
fig, ax = plt.subplots()

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))

ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0)) 

xx = np.linspace(-0.75, 1., 100)
ax.plot(xx, xx**3);

# %%
fig, ax = plt.subplots()

ax.spines['right'].set_color('blue')
ax.spines['top'].set_color('blue')

ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))

ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))

xx = np.linspace(-0.75, 1., 100)
ax.plot(xx, xx**3);

# %%
fig, ax = plt.subplots()

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.spines['bottom'].set_color('green')
ax.spines['left'].set_color('red')

ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0)) 

ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0)) 

xx = np.linspace(-0.75, 1., 100)
ax.plot(xx, xx**3,'c');

# %%
matplotlib.rcParams['xtick.major.pad'] = 5
matplotlib.rcParams['ytick.major.pad'] = 5

fig, ax = plt.subplots(1, 1)

ax.fill_between(x, x**2, x, np.exp(x), color="green", alpha=0.5);
ax.set_yticks([0, 50, 100, 150])

ax.set_title("label and axis spacing")

ax.xaxis.labelpad = 5
ax.yaxis.labelpad = 5

ax.set_xlabel("x")
ax.set_ylabel("y");

ax.fill_between(x, x**2, x, np.exp(x), color="green", alpha=0.5);

# %%
fig , ax= plt.subplots(1,1)

ax.scatter(xx, xx + 0.25*np.random.randn(len(xx)))
ax.set_title('scatter graph');

# %%
n=np.array([0,1,2,3,4,5])

# %%
n
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
fig , ax=plt.subplots(1,2,figsize=(12,6))

ax[0].scatter(xx, xx + 0.25*np.random.randn(len(xx)))
ax[0].set_title('scatter graph')

ax[1].step(n,n**2,lw=3)
ax[1].set_title('step graph');

# %%
fig , ax=plt.subplots(1,3,figsize=(12,4))

ax[0].scatter(xx, xx + 0.25*np.random.randn(len(xx)))
ax[0].set_title('scatter graph')

ax[1].step(n,n**2,lw=3)
ax[1].set_title('step graph')

ax[2].bar(n, n**2, align='center', width=0.5, alpha=0.5)
ax[2].set_title('bar graph');

# %%
fig , ax=plt.subplots(1,4,figsize=(12,3))

ax[0].scatter(xx, xx + 0.25*np.random.randn(len(xx)),color="red")
ax[0].set_title('scatter graph')

ax[1].step(n,n**2,color="violet",lw=3)
ax[1].set_title('step graph')

ax[2].bar(n, n**2,color="orange", align='center', width=0.5, alpha=0.5)
ax[2].set_title('bar graph');

ax[3].fill_between(x, x**2, x**3, color='green', alpha=0.5);
ax[3].set_title('fill_between graph');

# %%
fig , ax=plt.subplots(4,1,figsize=(3,12))

ax[0].scatter(xx, xx + 0.25*np.random.randn(len(xx)),color="red")
ax[0].set_title('scatter graph')

ax[1].step(n,n**2,color="violet",lw=3)
ax[1].set_title('step graph')

ax[2].bar(n, n**2,color="orange", align='center', width=0.5, alpha=0.5)
ax[2].set_title('bar graph');

ax[3].fill_between(x, x**2, x**3, color='green', alpha=0.5);
ax[3].set_title('fill_between graph');

fig.tight_layout()

# %%
fig , ax=plt.subplots(4,2,figsize=(6,12))

ax[0,0].scatter(xx, xx + 0.25*np.random.randn(len(xx)),color="red")
ax[0,0].set_title('scatter graph')

ax[1,1].step(n,n**2,color="violet",lw=3)
ax[1,1].set_title('step graph')

ax[2,0].bar(n, n**2,color="orange", align='center', width=0.5, alpha=0.5)
ax[2,0].set_title('bar graph');

ax[3,1].fill_between(x, x**2, x**3, color='green', alpha=0.5);
ax[3,1].set_title('fill_between graph');

fig.tight_layout()

# %%
fig , ax=plt.subplots(4,3,figsize=(8,12))

ax[0,0].scatter(xx, xx + 0.25*np.random.randn(len(xx)),color="red")
ax[0,0].set_title('scatter graph')

ax[0,1].set_title('none graph')

ax[0,2].scatter(xx, xx + 0.25*np.random.randn(len(xx)),color="red")
ax[0,2].set_title('scatter graph')

ax[1,0].set_title('none graph')

ax[1,1].step(n,n**2,color="violet",lw=3)
ax[1,1].set_title('step graph')

ax[1,2].set_title('none graph')

ax[2,0].bar(n, n**2,color="orange", align='center', width=0.5, alpha=0.5)
ax[2,0].set_title('bar graph');

ax[2,1].set_title('none graph')

ax[2,2].bar(n, n**2,color="orange", align='center', width=0.5, alpha=0.5)
ax[2,2].set_title('bar graph');

ax[3,0].set_title('none graph')

ax[3,1].fill_between(x, x**2, x**3, color='green', alpha=0.5);
ax[3,1].set_title('fill_between graph');

ax[3,2].set_title('none graph')

fig.tight_layout()

# %%
fig, ax = plt.subplots()

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))

ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))
xx = np.linspace(-0.75, 1., 100)

ax.fill_between(xx, xx**2, xx**3, color='red', alpha=0.5 , lw=2);
ax.set_title('fill_between graph');

ax.text(-0.5, 0.3, r"$y=x^2$", fontsize=15, color="r")
ax.text(-0.68,-0.4, r"$y=x^3$", fontsize=15, color="r");

# %%
x = np.linspace(1, 5 , 11)
y = x ** 2
fig, ax = plt.subplots()
ax.fill_between(x, x**2, x, np.exp(x) ,color='b', alpha=0.5);
ax.set_title('fill_between graph');

# %%
fig, ax = plt.subplots()

ax.plot(xx, xx**2, xx, xx**3)

ax.text(-0.5, 0.3, r"$y=x^2$", fontsize=20, color="blue")
ax.text(0.65, 0.1, r"$y=x^3$", fontsize=20, color="green");

# %%
fig,ax=plt.subplots(3,3)
fig.tight_layout()

# %%
fig = plt.figure()
ax1 = plt.subplot2grid((3,3), (0,0), colspan=3)
ax2 = plt.subplot2grid((3,3), (1,0), colspan=2)
ax3 = plt.subplot2grid((3,3), (1,2), rowspan=2)
ax4 = plt.subplot2grid((3,3), (2,0))
ax5 = plt.subplot2grid((3,3), (2,1))
fig.tight_layout()

# %%
fig = plt.figure()
ax1 = plt.subplot2grid((4,4), (0,0), colspan=3)
ax2 = plt.subplot2grid((4,4), (1,0), colspan=2)
ax3 = plt.subplot2grid((4,4), (1,2), rowspan=2)
ax3 = plt.subplot2grid((4,4), (0,3), rowspan=3)
ax4 = plt.subplot2grid((4,4), (2,0))
ax5 = plt.subplot2grid((4,4), (2,1))
fig.tight_layout()

# %%
import matplotlib.gridspec as gridspec

# %%
fig = plt.figure()

gs = gridspec.GridSpec(2, 3, height_ratios=[3,1], width_ratios=[2,4,8])
for g in gs:
    ax = fig.add_subplot(g)
    
fig.tight_layout()

# %%
fig = plt.figure()

gs = gridspec.GridSpec(3, 3, height_ratios=[3,1,4], width_ratios=[8,4,8])
for g in gs:
    ax = fig.add_subplot(g)
    
fig.tight_layout()

# %%
fig, ax = plt.subplots()

ax.plot(xx, xx**2, xx, xx**3)
fig.tight_layout()

inset_ax = fig.add_axes([0.3, 0.55, 0.35, 0.35])

inset_ax.plot(xx, xx**2, xx, xx**3)
inset_ax.set_title('zoom near origin')

inset_ax.set_xlim(-.2, .2)
inset_ax.set_ylim(-.005, .01)

inset_ax.set_yticks([0, 0.005, 0.01])
inset_ax.set_xticks([-0.1,0,.1]);

# %%
fig, ax = plt.subplots()

ax.plot(xx, xx**2, xx, xx**3)
fig.tight_layout()

inset_ax = fig.add_axes([0.3, 0.55, 0.35, 0.35])
inset=fig.add_axes([1.1,.3,0.5,0.5])

inset.plot(xx,xx**2,xx,xx**3)

inset.set_xlim(-.02, .02)
inset.set_ylim(-.0005, .001)

inset.set_yticks([0, 0.0005, 0.001])
inset.set_xticks([-0.01,0,0.01]);

inset_ax.plot(xx, xx**2, xx, xx**3)
inset_ax.set_title('zoom near origin')

inset_ax.set_xlim(-.2, .2)
inset_ax.set_ylim(-.005, .01)

inset_ax.set_yticks([0, 0.005, 0.01])
inset_ax.set_xticks([-0.1,0,.1]);
