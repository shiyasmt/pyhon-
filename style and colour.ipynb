# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
tips=sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.countplot(x='sex',data=tips)
plt.show()

# %%
sns.set_style('dark')
sns.countplot(x='sex',data=tips)
plt.show()

# %%
sns.set_style('ticks')
sns.countplot(x='sex',data=tips,palette='deep')
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13044\2811225396.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='sex',data=tips,palette='deep')

# %%
sns.countplot(x='sex',data=tips,palette='deep')
sns.despine()
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13044\3283255927.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='sex',data=tips,palette='deep')

# %%
sns.countplot(x='sex',data=tips,palette='deep')
sns.despine(left=True)
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13044\3771801253.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='sex',data=tips,palette='deep')

# %%
sns.countplot(x='sex',data=tips,palette='deep')
sns.despine(bottom=True,left=True)
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13044\681761111.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='sex',data=tips,palette='deep')

# %%
plt.figure(figsize=(12,4))
sns.countplot(x='sex',data=tips,palette='deep')
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13044\538666232.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='sex',data=tips,palette='deep')

# %%
plt.figure(figsize=(12,3))
sns.countplot(x='sex',data=tips,palette='deep')
sns.despine(left=True,bottom=True)
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13044\2518014183.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='sex',data=tips,palette='deep')

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,height=4,aspect=2,hue='sex',palette='coolwarm')
plt.show()

# %%
sns.set_context('poster',font_scale=1)
sns.countplot(x='sex',data=tips,palette='coolwarm')
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13044\943407529.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='sex',data=tips,palette='coolwarm')

# %%
plt.figure(figsize=(12,3))
sns.set_context('poster',font_scale=2)
sns.countplot(x='sex',data=tips,palette='coolwarm')
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13044\1714171001.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='sex',data=tips,palette='coolwarm')

# %%
plt.figure(figsize=(12,4))
sns.set_context('poster',font_scale=2)
sns.countplot(x='sex',data=tips,palette='coolwarm')
sns.despine(left=True,bottom=True)
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13044\361704903.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='sex',data=tips,palette='coolwarm')
